# %%
#Descriptive Statistics - Measures of Central Tendency and variability

# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_csv('tested.csv')

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %%
df.groupby('Age')['Fare'].mean()
# Out:
# Age
# 0.17      20.575000
# 0.33      14.400000
# 0.75      13.775000
# 0.83       9.350000
# 0.92      27.750000
#             ...
# 62.00      9.687500
# 63.00    123.889600
# 64.00     61.652767
# 67.00    221.779200
# 76.00     78.850000
# Name: Fare, Length: 79, dtype: float64

# %%
mode_a=df['Age'].mode()
print(mode_a)
# Out:
# 0    21.0
# 1    24.0
# Name: Age, dtype: float64

# %%
df.groupby('Age')['Fare'].median()
# Out:
# Age
# 0.17      20.5750
# 0.33      14.4000
# 0.75      13.7750
# 0.83       9.3500
# 0.92      27.7500
#            ...
# 62.00      9.6875
# 63.00    123.8896
# 64.00     75.2500
# 67.00    221.7792
# 76.00     78.8500
# Name: Fare, Length: 79, dtype: float64

# %%
df.groupby('Age')['Fare'].std()
# Out:
# Age
# 0.17           NaN
# 0.33           NaN
# 0.75           NaN
# 0.83           NaN
# 0.92           NaN
#            ...
# 62.00          NaN
# 63.00    138.43680
# 64.00     30.65597
# 67.00          NaN
# 76.00          NaN
# Name: Fare, Length: 79, dtype: float64

# %%
df.groupby('Age')['Fare'].min()
# Out:
# Age
# 0.17      20.5750
# 0.33      14.4000
# 0.75      13.7750
# 0.83       9.3500
# 0.92      27.7500
#            ...
# 62.00      9.6875
# 63.00     26.0000
# 64.00     26.5500
# 67.00    221.7792
# 76.00     78.8500
# Name: Fare, Length: 79, dtype: float64

# %%
df.groupby('Age')['Fare'].max()
# Out:
# Age
# 0.17      20.5750
# 0.33      14.4000
# 0.75      13.7750
# 0.83       9.3500
# 0.92      27.7500
#            ...
# 62.00      9.6875
# 63.00    221.7792
# 64.00     83.1583
# 67.00    221.7792
# 76.00     78.8500
# Name: Fare, Length: 79, dtype: float64

# %%
df.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass              Name   Sex  \
# count    418.000000  418.000000  418.000000               418   418
# unique          NaN         NaN         NaN               418     2
# top             NaN         NaN         NaN  Kelly, Mr. James  male
# freq            NaN         NaN         NaN                 1   266
# mean    1100.500000    0.363636    2.265550               NaN   NaN
# std      120.810458    0.481622    0.841838               NaN   NaN
# min      892.000000    0.000000    1.000000               NaN   NaN
# 25%      996.250000    0.000000    1.000000               NaN   NaN
# 50%     1100.500000    0.000000    3.000000               NaN   NaN
# 75%     1204.750000    1.000000    3.000000               NaN   NaN
# max     1309.000000    1.000000    3.000000               NaN   NaN
#
#                Age       SibSp       Parch    Ticket        Fare  \
# count   332.000000  418.000000  418.000000       418  417.000000
# ...

# %%
#point 2
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('Iris.csv')

# %%
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
data.groupby('Species')['SepalLengthCm'].sum()
# Out:
# Species
# Iris-setosa        250.3
# Iris-versicolor    296.8
# Iris-virginica     329.4
# Name: SepalLengthCm, dtype: float64

# %%
data.groupby('Species')['SepalLengthCm'].mean()
# Out:
# Species
# Iris-setosa        5.006
# Iris-versicolor    5.936
# Iris-virginica     6.588
# Name: SepalLengthCm, dtype: float64

# %%
data.groupby('Species')['SepalLengthCm'].median()
# Out:
# Species
# Iris-setosa        5.0
# Iris-versicolor    5.9
# Iris-virginica     6.5
# Name: SepalLengthCm, dtype: float64

# %%
data['SepalLengthCm'].mode()
# Out:
# 0    5.0
# Name: SepalLengthCm, dtype: float64

# %%
data.groupby('Species')['SepalLengthCm'].std()
# Out:
# Species
# Iris-setosa        0.352490
# Iris-versicolor    0.516171
# Iris-virginica     0.635880
# Name: SepalLengthCm, dtype: float64

# %%
# Calculate the 50th percentile (median)
np.percentile(data['SepalWidthCm'],75)
# Out:
# 3.3
